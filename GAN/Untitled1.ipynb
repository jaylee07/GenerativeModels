# %%
from IPython.display import Image
Image("/home/jehyuk/GenerativeModels/GAN/results/DCGAN/CIFAR10/fake_samples_epoch_007.png", width = 512, height=512)

# %%
Image("/home/jehyuk/GenerativeModels/GAN/results/DCGAN/CIFAR10/DCGAN_epoch003.png", width = 512, height=512)
